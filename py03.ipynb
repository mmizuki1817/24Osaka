# %% [markdown]
# <a href="https://colab.research.google.com/github/mmizuki1817/24Osaka/blob/main/py03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# アップルの株を買いたいと想像してください。株式市場では、「安く買って、高く売る」だけでいいのです。例えば、ある銘柄を青いポイントで買って、赤いポイントで売れば、30ドルの儲けだ。簡単そうでしょう？しかし、現実はそう簡単ではない。なぜなら、未来はわからないからだ。
#
# では、どうやって将来の価格を予測するのでしょうか？方法は2つある。ひとつはファンダメンタルズ分析と呼ばれる方法です。アップルは本当に良い会社ですが、時には悪いニュースも発表します。例えば、赤い矢印で示した地点でAppleはEpic Gamesとの訴訟に敗訴している。この分析方法は非常に堅実ですが、常に警戒してニュースや財務諸表に目を通す必要があります。一方、過去の価格から現在の価格が「相対的に安いのか、割高なのか」を推測することもできます。これがいわゆるテクニカル分析です。この講座では、よく使われる4つのテクニカル指標(MA（移動平均線）、MACD（移動平均収束・発散）、RSI（相対力指数）、BB（ボリンジャーバンド))を学びます。

# %% [markdown]
# ex00 Make an account at TradingView and display the chart of AAPL.
# (e.g. what does the candlestick signify?)
# ->done

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ex01 MA(Moving Average Line)をGoogleで検索し、TradingViewを使ってAPPLをプロットします。50日MAと100日MAを使用 がどのように機能するかを見てみましょう。
# 参考https://yuki.world/tradingview-3ma/
# ->インジケーターf(x):MA Cross(移動平均線の交差）50 100
# ->done

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ex02 他の指標と一緒にプロットして、同じことをします。
# 参考BBhttps://www.smbcnikko.co.jp/terms/japan/ho/J0054.html
# ->f(x):BB
# ->done

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ex03 2021年のAppleの株価を50日MAと100日MAでプロットしてください。
# (mplfinance(matplotlib for finance)というPythonのツールがあります。)

# %%
# !pip install mplfinance

# %%
# !pip install TA_Lib
# Out:
# ...
#   Using cached TA-Lib-0.4.24.tar.gz (269 kB)
# ...
#   ERROR: Failed building wheel for TA-Lib
#   Running setup.py clean for TA-Lib
# Failed to build TA-Lib
# ...
#     Running setup.py install for TA-Lib ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-uc5_u_mm/ta-lib_f80ac371c8624686a35d3d384eee1794/setup.py'"'"'; __file__='"'"'/tmp/pip-install-uc5_u_mm/ta-lib_f80ac371c8624686a35d3d384eee1794/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-g6q7ndn7/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/TA-Lib Check the logs for full command output.

# %%
import talib as ta
ta.get_functions()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-75ebbd7f2ffb> in <module>()
# ----> 1 import talib as ta
#       2 ta.get_functions()
#
# ModuleNotFoundError: No module named 'talib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ex04 Make a plot of the Apple’s stock price in 2021 with the 12 and 26 days MACD with Python.
# (9 days smoothing. You can either define your own functions or import talib.)
# 2021年のAppleの株価を12日、26日のMACDでプロットしてください。
# (9日平滑化。自分で関数を定義してもいいし、talibをインポートしてもいい。)

# %% [markdown]
# ex05 Make a plot of the Apple’s stock price in 2021 with the 14 days RSI with Python.
# Pythonで2021年のAppleの株価と14日RSIのプロットを作成しなさい。

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ex06 2021年のAppleの株価を2σのBBでPythonでプロットしてください。
# (最終的にはこのようなプロットになるはずです)。
