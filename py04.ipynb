# %% [markdown]
# <a href="https://colab.research.google.com/github/mmizuki1817/24Osaka/blob/main/py04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ex00 Create a Class named “Osaka”.
# Using the init method, store the name to the member variable.
# > Me = Osaka(”Atsushi”)
# > print(Me.member)
# Atsushi

# %% [markdown]
# ex01 Add output method to print out the welcoming message.   >Me=Osaka(”Atsushi”)
# >Me.output()
# Welcome to 24Osaka, Atsushi!

# %% [markdown]
# ex02 Add the donation and check donation method to ask for some money.
# >Me=Osaka(”Atsushi”)
# >Me.check donation()
# >while Me.money < 10000:
# > Me.donation()
# > Me.check donation()
# Your current donation is : 0
# I would appreciate it if you could give us more money.
# How much money do you pay to support us?
# > 100
# Your current donation is : 100
# I would appreciate it if you could give us more money.
# How much money do you pay to support us?
# > 9900
# Your current donation is : 10000
# Thank you sir!

# %% [markdown]
# ex03 Create Nagasaki class that inherits Osaka’s methods.
# >Me=Nagasaki(”Atsushi”)
# >Me.check donation()
# >while Me.money < 10000:
# > Me.donation()
# > Me.check donation()
# Your current donation is : 0
# I would appreciate it if you could give us more money.
# How much money do you pay to support us?
# > 100
# Your current donation is : 100
# I would appreciate it if you could give us more money.
# How much money do you pay to support us?
# > 9900
# Your current donation is : 10000
# Thank you sir!

# %% [markdown]
# Define the function named MACD that returns the values of the MACD and MACD
# signals.
# def MACD(close, n1, n2, ns):
# —-(your code)
# —-return macd, macdsignal

# %% [markdown]
# ex05 From backtesting import Backtest, Strategy, and lib.crossover. Define the Class named
# MACDCross that inherits the Strategy class. You can implement the strategy by
# incorporating these methods.
# def init(self):
# —-self.macd, self.macdsignal = self.I(MACD, self.data.Close, self.n1, self.n2, self.ns)
# def next(self):
# —-if crossover(self.macd, self.macdsignal):
# ——–self.buy()
# —-elif crossover(self.macdsignal, self.macd):
# ——–self.position.close()

# %% [markdown]
# ![スクリーンショット.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# APPL(df)のデータでバックテストしてみましょう。以下のコマンドを入力することで 下図のようになります。
# bt = Backtest(df, MACDCross, cash=1000, commission=0.  001, margin=1.0,
# 終値で取引=True, 限定注文=True)
# 出力 = bt.run()
# print(出力)
# bt.plot()
